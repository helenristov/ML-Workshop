# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://cdn2.hubspot.net/hubfs/438089/docs/training/dblearning-banner.png" alt="Databricks Learning" width="555" height="64">
# </div>

# %% [markdown]
# &copy; 2018 Databricks, Inc. All rights reserved.<br/>

# %% [markdown]
# ### Why Contoso Needs a Data Lake
# * Store both big and small data in one location for all personas - Data Engineering, Data Science, Analysts
# * They need to access this data in diffrent languages and tools - SQL, Python, Scala, Java, R with Notebooks, IDE, Power BI, Tableau, JDBC/ODBC
#
# ### Azure Databricks Solutions
# * Azure Storage or Azure Data Lake - Is a place to store all data, big and small
# * Access both big (TB to PB) and small data easily with Databricks' scaleable clusters
# * Use Python, Scala, R, SQL, Java

# %% [markdown]
# ####Azure Databricks for Batch ETL & Data Engineers
#
# ![arch](https://kpistoropen.blob.core.windows.net/collateral/roadshow/azure_roadshow_de.png)

# %% [markdown]
# # Reading & Writting Data to/from files - Parquet and CSV
#
# **Technical Accomplishments:**
# - Read data from CSV
# - Write out data in optimal Parquet format with Schema

# %% [markdown]
# ##![Spark Logo Tiny](https://kpistoropen.blob.core.windows.net/collateral/roadshow/logo_spark_tiny.png) Reading from CSV

# %% [markdown]
# ### The Data Source
# * For this exercise, we will be using a file called **products.csv**.
# * The data represents new products we are planning to add to our online store.
# * We can use **&percnt;head ...** to view the first few lines of the file.

# %%
# %fs ls /mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv</td><td>product.csv</td><td>3449</td></tr></tbody></table></div>

# %%
# %fs head /mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">product_id,category,brand,model,price,processor,size,display
# 1,Laptops ,HP,&quot;Spectre x360 2-in-1 13.3&quot;&quot; 4K Ultra HD Touch-Screen Laptop&quot;,1499.989990234375,null,null,null
# 2,Laptops ,Microsoft,&quot;Surface Pro – 12.3&quot;&quot;&quot;,1299.989990234375,null,null,null
# 3,Laptops ,Microsoft,&quot;Surface Book 2 - 13.5&quot;&quot;&quot;,1499.989990234375,null,null,null
# 4,Laptops ,Dell,&quot;XPS 2-in-1 13.3&quot;&quot;&quot;,1949.989990234375,null,null,null
# 5,Laptops ,Lenovo,&quot;Yoga 920 2-in-1 13.9&quot;&quot;&quot;,1799.989990234375,null,null,null
# 6,Laptops ,Apple ,&quot;MacBook Pro - 15&quot;&quot; Display&quot;,2659.989990234375,null,null,null
# 7,Laptops ,Apple ,&quot;MacBook Pro - 13&quot;&quot; Display&quot;,1499.989990234375,null,null,null
# 8,Laptops ,Apple ,&quot;MacBook Pro - 15.4&quot;&quot; Display&quot;,1999.989990234375,null,null,null
# 9,Laptops ,Apple ,&quot;MacBook Air - 13.3&quot;&quot; Display&quot;,999.989990234375,null,null,null
# 10,Laptops ,HP,&quot;Pavilion x360 2-in-1 14&quot;&quot; Touch-Screen Laptop&quot;,999.989990234375,null,null,null
# 11,Laptops ,Dell,&quot;2-in-1 17.3&quot;&quot; Touch-Screen Laptop&quot;,1299.989990234375,null,null,null
# 32,tablets,Fujitsu,Stylistic Q737 ,299.99,Core-i,&quot;13.3&quot;&quot;&quot;&quot;&quot;,1920×1080 (16:9)
# 33,tablets,Dell,Latitude 7285 2-in-1 ,299.99,Core-m,12.3”,2880×1920 (3:2)
# 34,tablets,Dell,Latitude 5285 2-in-1 ,299.99,Core-i,&quot;&quot;&quot;12.3&quot;&quot;&quot;&quot; &quot;&quot;&quot;,920×1280 (3:2)
# 35,tablets,ASUS,Transformer Pro (T304) ,299.99,Core-i,&quot;12.6&quot;&quot;&quot;&quot;&quot;,2160×1440 (3:2)
# 36,tablets,Lenovo&amp;amp;reg;,Miix 720 ,299.99,Core-i,&quot;12.0&quot;&quot;&quot;&quot;&quot;,2880×1920 (3:2)
# 37,tablets,Lenovo&amp;amp;reg;,Thinkpad X1 Tablet (2017) ,299.99,Core-m,&quot;&quot;&quot;12.0&quot;&quot;&quot;&quot; &quot;&quot;&quot;,2160×1440 (3:2)
# 38,tablets,Cube&amp;amp;reg;,Mix Plus ,299.99,Core-m,&quot;10.6&quot;&quot;&quot;&quot;&quot;,1920×1080 (16:9)
# 39,tablets,Eve ,V (Project Pyramid Flipper) ,299.99,Core-m,&quot;&quot;&quot;12.3&quot;&quot;&quot;&quot; &quot;&quot;&quot;,2736×1824 (3:2)
# 40,tablets,Fujitsu,Stylistic R727 ,299.99,Core-i,&quot;&quot;&quot;12.5&quot;&quot;&quot;&quot; &quot;&quot;&quot;,1920×1080 (16:9)
#
# </div>

# %% [markdown]
# ### Option #1 - Read The CSV File, creating a DF
# Let's start with the bare minimum by specifying that the file we want to read is delimited and the location of the file:
# The default delimiter for `spark.read.csv( )` is comma but we can change by specifying the option delimiter parameter.

# %%
csvFile = "/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = (spark.read                        # The DataFrameReader
   .option("header", "true")       # Use first line of all files as header
   .option("inferSchema", "true")  # Automatically infer data types
   .csv(csvFile)                   # Creates a DataFrame from CSV after reading in the file
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td
# %% [markdown]
# ### Option #2 Create a SQL view, inferring the schema

# %%
# %sql

DROP TABLE IF EXISTS contoso_products; 
CREATE OR REPLACE TEMPORARY VIEW contoso_products
USING CSV
OPTIONS (path "/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/", header "true", inferSchema "true")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

SELECT * FROM contoso_products
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>11</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>12</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 Pro 13.3"" Touch-Screen Laptop"</td><td>1099.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>13</td><td>Laptops </td><td>Google</td><td>"Pixelbook 12.3"" Touchscreen Chromebook"</td><td>1699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>14</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 spin 13.3"" Touch-Screen Laptop"</td><td>1199.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>15</td><td>Laptops </td><td>Dell</td><td>"15.6"" Laptop"</td><td>2279.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>Laptops </td><td>Microsoft</td><td>"Surface Book 13.5"" Touch Screen with Performance Base"</td><td>2399.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>18</td><td>Laptops </td><td>Lenovo</td><td>"Star Wars Special Edition Galactic Empire - Yoga 910 2-in-1 13.9"" Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>19</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3”</td><td>2699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>20</td><td>Laptops </td><td>Lenovo</td><td>"15.6"" Laptop"</td><td>2499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>21</td><td>tablets</td><td>HP&amp;reg;</td><td>Envy x2 (2018)</td><td>299.99</td><td>Core-m</td><td>12.3""""</td><td>1920×1280 (16:9)</td></tr><tr><td>22</td><td>tablets</td><td>Chuwi&amp;reg;</td><td>CoreBook</td><td>299.99</td><td>Core-m </td><td>13.3""""</td><td>1920×1080 (16:9) </td></tr><tr><td>23</td><td>tablets</td><td>Microsoft</td><td>Surface Pro (2017) </td><td>299.99</td><td>Core-m/-i</td><td>12.3""""</td><td>2736×1824 (3:2)</td></tr><tr><td>24</td><td>tablets</td><td>Huawai</td><td>Matebook E </td><td>299.99</td><td>Core-m</ ...

# %% [markdown]
# Create a persistent table

# %%
# %sql
DROP TABLE IF EXISTS contoso_products_persistent;
CREATE Table contoso_products_persistent
USING CSV
OPTIONS (path "/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/", header "true", inferSchema "true")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Now one might think that this would actually print out the values of the `DataFrame` that we just parallelized, however that's not quite how Apache Spark works. Spark allows two distinct kinds of operations by the user. There are **transformations** and there are **actions**.
#
# ### Transformations
#
# Transformations are operations that will not be completed at the time you write and execute the code in a cell - they will only get executed once you have called a **action**. An example of a transformation might be to convert an integer into a float or to filter a set of values.
#
# ### Actions
#
# Actions are commands that are computed by Spark right at the time of their execution. They consist of running all of the previous transformations in order to get back an actual result. An action is composed of one or more jobs which consists of tasks that will be executed by the workers in parallel where possible
#
# Here are some simple examples of transformations and actions. Remember, these **are not all** the transformations and actions - this is just a short sample of them. We'll get to why Apache Spark is designed this way shortly!
#
# ![transformations and actions](https://training.databricks.com/databricks_guide/gentle_introduction/trans_and_actions.png)

# %% [markdown]
# This can be costly when reading in a large file as spark is forced to read through all the data in the files in order to determine data types.  To read in a file and avoid this costly extra job we can provide the schema to the DataFrameReader.

# %% [markdown]
# ### Option #3 Create a Dataframe with a given schema
#
# This time we are going to read the same file.
#
# The difference here is that we are going to define the schema beforehand to avoid the execution of any extra jobs.

# %% [markdown]
# Declare the schema.
#
# This is just a list of field names and data types.

# %%
# Required for StructField, StringType, IntegerType, etc.
from pyspark.sql.types import *

csvSchema = StructType([
  StructField("product_id", LongType(), True),
  StructField("category", StringType(), True),
  StructField("brand", StringType(), True),
  StructField("model", StringType(), True),
  StructField("price", DoubleType(), True),
  StructField("processor", StringType(), True),
  StructField("size", StringType(), True),
  StructField("display", StringType(), True)
 ])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Read in our data (and print the schema).
#
# We can specify the schema, or rather the `StructType`, with the `schema(..)` command:

# %%
productDF = (spark.read                   # The DataFrameReader
  .option('header', 'true')   # Ignore line #1 - it's a header
  .schema(csvSchema)          # Use the specified schema
  .csv(csvFile)               # Creates a DataFrame from CSV after reading in the file
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# With our DataFrame created, we can now create a temporary view and then view the data via SQL:

# %%
display(productDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td
989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
productDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>40
# </div>

# %%
# %sql
select count(*) from contoso_products_df
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>40</td></tr></tbody></table></div>

# %% [markdown]
# And now we can take a peak at the data with simple SQL SELECT statement:

# %% [markdown]
# <h2 style="color:green">Tip</h2>
#
# * Switch Languages (SQL, Scala, R, Shell, File System)
# * JDBC/ODBC!

# %% [markdown]
# <h2 style="color:green">Collaboration example</h2>
#
# * Live comments
# * Revision history

# %%
# %sql
SELECT * FROM contoso_products
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>11</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>12</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 Pro 13.3"" Touch-Screen Laptop"</td><td>1099.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>13</td><td>Laptops </td><td>Google</td><td>"Pixelbook 12.3"" Touchscreen Chromebook"</td><td>1699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>14</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 spin 13.3"" Touch-Screen Laptop"</td><td>1199.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>15</td><td>Laptops </td><td>Dell</td><td>"15.6"" Laptop"</td><td>2279.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>Laptops </td><td>Microsoft</td><td>"Surface Book 13.5"" Touch Screen with Performance Base"</td><td>2399.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>18</td><td>Laptops </td><td>Lenovo</td><td>"Star Wars Special Edition Galactic Empire - Yoga 910 2-in-1 13.9"" Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>19</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3”</td><td>2699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>20</td><td>Laptops </td><td>Lenovo</td><td>"15.6"" Laptop"</td><td>2499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>21</td><td>tablets</td><td>HP&amp;reg;</td><td>Envy x2 (2018)</td><td>299.99</td><td>Core-m</td><td>12.3""""</td><td>1920×1280 (16:9)</td></tr><tr><td>22</td><td>tablets</td><td>Chuwi&amp;reg;</td><td>CoreBook</td><td>299.99</td><td>Core-m </td><td>13.3""""</td><td>1920×1080 (16:9) </td></tr><tr><td>23</td><td>tablets</td><td>Microsoft</td><td>Surface Pro (2017) </td><td>299.99</td><td>Core-m/-i</td><td>12.3""""</td><td>2736×1824 (3:2)</td></tr><tr><td>24</td><td>tablets</td><td>Huawai</td><td>Matebook E </td><td>299.99</td><td>Core-m</ ...

# %% [markdown]
# ### Option #4 Create a SQL table w/ user-defined schema

# %%
# %sql 
DROP TABLE IF EXISTS contoso_products_manual;
CREATE TABLE contoso_products_manual (
  product_id int, 
  category string, 
  brand string, 
  model string, 
  price double,
  processor string,
  size string,
  display string)
USING CSV
OPTIONS (path "/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/", header "true")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df_from_sql = table("contoso_products_manual")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://kpistoropen.blob.core.windows.net/collateral/roadshow/logo_spark_tiny.png) Writing to Parquet
#
# * Parquet is a file format that is supported by many other data processing systems.
#
# * Parquet files are a columnar file format that Databricks highly recommends for customers.
#
# * Parquet files provide optimizations under the hood to speed up queries and are far more efficient file format than csv or json.
#
# * Spark SQL provides support for both reading and writing Parquet files that automatically preserves the schema of the original data. When writing Parquet files, all columns are automatically converted to be nullable for compatibility reasons.
#
# More discussion on <a href="http://parquet.apache.org/documentation/latest/" target="_blank">Parquet</a>
#
# Documentation on <a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=dataframe%20reader#pyspark.sql.DataFrameReader" target="_blank">DataFrameReader</a>

# %%
#Write to the file store
writeBase = "dbfs:/workshop/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Define path where to write to -- by default, in this workshop, we write to the workspace filestore
writeBase = "dbfs:/workshop/"
writePath = writeBase + "contoso_products.parquet"

#If there are multiple users working on the same instance, please use this writeBase, adding your $USERNAME to the path, and to any subsequent write/read
#writeBase = writeBase = "dbfs:/workshop/$USERNAME/"
#writePath = writeBase + "contoso_products.parquet"

#As backup, you can always write to this blob
#writeBase = "dbfs:/mnt/databricks-workshop-exercises/Contoso-retail/initech/"
#writePath = writeBase + "contoso_products.parquet"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
productDF.write.mode("overwrite").parquet(writePath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# we can see the parquet file in the file system

# %%
print(writePath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/workshop/contoso_products.parquet
# </div>

# %%
# %fs ls dbfs:/workshop/contoso_products.parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/workshop/contoso_products.parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/workshop/contoso_products.parquet/_committed_2556813255054112978</td><td>_committed_2556813255054112978</td><td>228</td></tr><tr><td>dbfs:/workshop/contoso_products.parquet/_committed_4700619820145654838</td><td>_committed_4700619820145654838</td><td>121</td></tr><tr><td>dbfs:/workshop/contoso_products.parquet/_committed_vacuum3576009207923724906</td><td>_committed_vacuum3576009207923724906</td><td>96</td></tr><tr><td>dbfs:/workshop/contoso_products.parquet/_started_2556813255054112978</td><td>_started_2556813255054112978</td><td>0</td></tr><tr><td>dbfs:/workshop/contoso_products.parquet/part-00000-tid-2556813255054112978-6aeb910f-0112-4a7c-a6f6-a4cc52b9e7f2-18-c000.snappy.parquet</td><td>part-00000-tid-2556813255054112978-6aeb910f-0112-4a7c-a6f6-a4cc52b9e7f2-18-c000.snappy.parquet</td><td>3759</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://kpistoropen.blob.core.windows.net/collateral/roadshow/logo_spark_tiny.png) Writing to Parquet using SQL

# %%
# %sql 
DROP TABLE IF EXISTS contoso_products_parquet;
CREATE TABLE contoso_products_parquet
USING parquet
-- this path might need to be changed based on where you have been writing to
OPTIONS (path = "dbfs:/workshop/sqlwrite/contoso_products.parquet")
AS 
SELECT * FROM contoso_products
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls dbfs:/workshop/sqlwrite/contoso_products.parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/_committed_1352254798129581626</td><td>_committed_1352254798129581626</td><td>228</td></tr><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/_committed_5288512592291700470</td><td>_committed_5288512592291700470</td><td>121</td></tr><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/_committed_vacuum6023087286022087975</td><td>_committed_vacuum6023087286022087975</td><td>96</td></tr><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/_started_1352254798129581626</td><td>_started_1352254798129581626</td><td>0</td></tr><tr><td>dbfs:/workshop/sqlwrite/contoso_products.parquet/part-00000-tid-1352254798129581626-aad307ca-85c1-499b-bc9b-41e505a9c7db-19-c000.snappy.parquet</td><td>part-00000-tid-1352254798129581626-aad307ca-85c1-499b-bc9b-41e505a9c7db-19-c000.snappy.parquet</td><td>3641</td></tr></tbody></table></div>

# %% [markdown]
# ## Next Step
#
# [Transformations-Actions]($../2-ETL/2-02 Transformations-Actions)

# %% [markdown]
# &copy; 2018 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
