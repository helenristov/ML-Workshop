# %% [markdown]
# -sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://cdn2.hubspot.net/hubfs/438089/docs/training/dblearning-banner.png" alt="Databricks Learning" width="555" height="64">
# </div>

# %% [markdown]
# #Introduction to Transformations and Actions
#
# **Technical Accomplishments:**
# * Develop familiarity with the `DataFrame` APIs
# * Introduce transformations and actions
# * Sharing/exporting notebooks

# %% [markdown]
# The data is located at `dbfs:/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv`.

# %%
# %fs ls /mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv</td><td>product.csv</td><td>3449</td></tr></tbody></table></div>

# %%
csvDir = "dbfs:/mnt/databricks-workshop-datasets/Contoso-retail/initech/productsCsv/product.csv"

retailDF = (spark                    # Our SparkSession & Entry Point
           .read                     # Our DataFrameReader
           .option("header", "true")
           .option("inferSchema", "true")
           .csv(csvDir))           # Returns an instance of DataFrame
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) Our Data
#
# Let's continue by taking a look at the type of data we have.
#
# We can do this with the `printSchema()` command:

# %%
retailDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- product_id: integer (nullable = true)
# -- category: string (nullable = true)
# -- brand: string (nullable = true)
# -- model: string (nullable = true)
# -- price: double (nullable = true)
# -- processor: string (nullable = true)
# -- size: string (nullable = true)
# -- display: string (nullable = true)
#
# </div>

# %%
retailDF.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+--------------------+-----------------+---------+----+-------+
# product_id|category|    brand|               model|            price|processor|size|display|
# +----------+--------+---------+--------------------+-----------------+---------+----+-------+
#          1|Laptops |       HP|&quot;Spectre x360 2-i...|1499.989990234375|     null|null|   null|
#          2|Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;|1299.989990234375|     null|null|   null|
#          3|Laptops |Microsoft|Surface Book 2 - ...|1499.989990234375|     null|null|   null|
# +----------+--------+---------+--------------------+-----------------+---------+----+-------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# We should now be able to see that we have eight columns of data:
# * **product_id** (*string*) Unique product identifier.
# * **category** (*string*): The product is either a tablet or a laptop.
# * **brand** (*string*): The name of the product's brand.
# * **model** (*string*): The name of the product's model.
# * **price** (*double*): Price of the product.
# * **processor** (*string*): The type of processor the product uses.
# * **size** (*string*): The size of the product in inches.
# * **display** (*string*): The aspect-ratio of the display.

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) show(..)
#
# The `show(..)` method has two optional parameters:
# * **n**: The number of records to print to the console, the default being 20.
# * **truncate**: If true, columns wider than 20 characters will be truncated, where the default is true.
#
# Let's take a look at the data in our `DataFrame` with the `show()` command.
#
# [Python Docs](https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=show#pyspark.sql.DataFrame.show)
#
# [Scala Docs](https://spark.apache.org/docs/latest/api/scala/#org.apache.spark.sql.Dataset)

# %%
retailDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+--------------------+-----------------+---------+----+-------+
# product_id|category|    brand|               model|            price|processor|size|display|
# +----------+--------+---------+--------------------+-----------------+---------+----+-------+
#          1|Laptops |       HP|&quot;Spectre x360 2-i...|1499.989990234375|     null|null|   null|
#          2|Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;|1299.989990234375|     null|null|   null|
#          3|Laptops |Microsoft|Surface Book 2 - ...|1499.989990234375|     null|null|   null|
#          4|Laptops |     Dell|   XPS 2-in-1 13.3&quot;&quot;|1949.989990234375|     null|null|   null|
#          5|Laptops |   Lenovo|Yoga 920 2-in-1 1...|1799.989990234375|     null|null|   null|
#          6|Laptops |   Apple |&quot;MacBook Pro - 15...|2659.989990234375|     null|null|   null|
#          7|Laptops |   Apple |&quot;MacBook Pro - 13...|1499.989990234375|     null|null|   null|
#          8|Laptops |   Apple |&quot;MacBook Pro - 15...|1999.989990234375|     null|null|   null|
#          9|Laptops |   Apple |&quot;MacBook Air - 13...| 999.989990234375|     null|null|   null|
#         10|Laptops |       HP|&quot;Pavilion x360 2-...| 999.989990234375|     null|null|   null|
#         11|Laptops |     Dell|&quot;2-in-1 17.3&quot;&quot; To...|1299.989990234375|     null|null|   null|
#         12|Laptops |  Samsung|&quot;Notebook 9 Pro 1...|1099.989990234375|     null|null|   null|
#         13|Laptops |   Google|&quot;Pixelbook 12.3&quot;&quot;...|1699.989990234375|     null|null|   null|
#         14|Laptops |  Samsung|&quot;Notebook 9 spin ...|1199.989990234375|     null|null|   null|
#         15|Laptops |     Dell|     &quot;15.6&quot;&quot; Laptop&quot;|2279.989990234375|     null|null|   null|
#         16|Laptops |     Dell|&quot;2-in-1 17.3&quot;&quot; To...|1299.989990234375|     null|null|   null|
#         17|Laptops |Microsoft|&quot;Surface Book 13....|2399.989990234375|     null|null|   null|
#         18|Laptops |   Lenovo|&quot;Star Wars Specia...|1299.989990234375|     null|null|   null|
#         19|Laptops |Microsoft| Surface Pro – 12.3”|2699.989990234375|     null|null|   null|
#         20|Laptops |   Lenovo|     &quot;15.6&quot;&quot; Laptop&quot;|2499.989990234375|     null|null|   null|
# +----------+--------+---------+--------------------+-----------------+---------+----+-------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# In the cell above, change the parameters of the show command to:
# * print only the first 5 records
# * disable truncation
# * print only the first 10 records and disable truncation
#
# **Note:** The function `show(..)` is an **action** which triggers a job.

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) display(..)
#
# The `show(..)` command is part of the core Spark API and simply prints the results to the console.
#
# Our notebooks have a slightly more elegant alternative.
#
# Instead of calling `show(..)` on an existing `DataFrame` we can instead pass our `DataFrame` to the `display(..)` command:

# %%
retailDF.select
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>&lt;bound method DataFrame.select of DataFrame[product_id: int, category: string, brand: string, model: string, price: double, processor: string, size: string, display: string]&gt;
# </div>

# %%
display(retailDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>11</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>12</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 Pro 13.3"" Touch-Screen Laptop"</td><td>1099.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>13</td><td>Laptops </td><td>Google</td><td>"Pixelbook 12.3"" Touchscreen Chromebook"</td><td>1699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>14</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 spin 13.3"" Touch-Screen Laptop"</td><td>1199.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>15</td><td>Laptops </td><td>Dell</td><td>"15.6"" Laptop"</td><td>2279.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>Laptops </td><td>Microsoft</td><td>"Surface Book 13.5"" Touch Screen with Performance Base"</td><td>2399.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>18</td><td>Laptops </td><td>Lenovo</td><td>"Star Wars Special Edition Galactic Empire - Yoga 910 2-in-1 13.9"" Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>19</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3”</td><td>2699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>20</td><td>Laptops </td><td>Lenovo</td><td>"15.6"" Laptop"</td><td>2499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>21</td><td>tablets</td><td>HP&amp;reg;</td><td>Envy x2 (2018)</td><td>299.99</td><td>Core-m</td><td>12.3""""</td><td>1920×1280 (16:9)</td></tr><tr><td>22</td><td>tablets</td><td>Chuwi&amp;reg;</td><td>CoreBook</td><td>299.99</td><td>Core-m </td><td>13.3""""</td><td>1920×1080 (16:9) </td></tr><tr><td>23</td><td>tablets</td><td>Microsoft</td><td>Surface Pro (2017) </td><td>299.99</td><td>Core-m/-i</td><td>12.3""""</td><td>2736×1824 (3:2)</td></tr><tr><td>24</td><td>tablets</td><td>Huawai</td><td>Matebook E </td><td>299.99</td><td>Core-m</ ...

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) limit(..)
#
# Both `show(..)` and `display(..)` are **actions** that trigger jobs (though in slightly different ways).
#
# If you recall, `show(..)` has a parameter to control how many records are printed but `display(..)` does not.
#
# We can address that difference with our first transformation, `limit(..)`.
#
# If you look at the API docs, `limit(..)` is described like this:
# > Returns a new Dataset by taking the first n rows...
#
# `show(..)`, like many actions, does not return anything.
#
# On the other hand, transformations like `limit(..)` return a **new** `DataFrame`:

# %%
limitedDF = retailDF.limit(5) # "limit" the number of records to the first 5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Nothing Happened
# * Notice how "nothing" happened - that is no job was triggered.
# * This is because we are simply defining the second step in our transformations.
#   0. Read in the parquet file (represented by **retailDF**).
#   0. Limit those records to just the first 5 (represented by **limitedDF**).
# * It's not until we induce an action that a job is triggered and the data is processed
#
# We can induce a job by calling either the `show(..)` or the `display(..)` actions:

# %%
limitedDF.show(100, False) #show up to 100 records and don't truncate the columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+------------------------------------------------------------+-----------------+---------+----+-------+
# product_id|category|brand    |model                                                       |price            |processor|size|display|
# +----------+--------+---------+------------------------------------------------------------+-----------------+---------+----+-------+
# 1         |Laptops |HP       |&quot;Spectre x360 2-in-1 13.3&quot;&quot; 4K Ultra HD Touch-Screen Laptop&quot;|1499.989990234375|null     |null|null   |
# 2         |Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;                                        |1299.989990234375|null     |null|null   |
# 3         |Laptops |Microsoft|Surface Book 2 - 13.5&quot;&quot;                                     |1499.989990234375|null     |null|null   |
# 4         |Laptops |Dell     |XPS 2-in-1 13.3&quot;&quot;                                           |1949.989990234375|null     |null|null   |
# 5         |Laptops |Lenovo   |Yoga 920 2-in-1 13.9&quot;&quot;                                      |1799.989990234375|null     |null|null   |
# +----------+--------+---------+------------------------------------------------------------+-----------------+---------+----+-------+
#
# </div>

# %%
display(limitedDF) # defaults to the first 1000 records
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### Why is Laziness So Important?
#
# This is a common pattern in functional programming as well as with Big Data specific languages.
# * We see it in Scala as part of its core design.
# * Java 8 introduced the concept with its Streams API.
# * And many functional programming languages have similar APIs.
#
# It has a number of benefits
# * Not forced to load all data at step #1
#   * Technically impossible with **REALLY** large datasets.
# * Easier to parallelize operations
#   * N different transformations can be processed on a single data element, on a single thread, on a single machine.
# * Most importantly, it allows the framework to automatically apply various optimizations

# %% [markdown]
# ### Catalyst Optimizer
#
# Because our API is declarative a large number of optimizations are available to us.
#
# Some of the examples include:
#   * Optimizing data type for storage
#   * Rewriting queries for performance
#   * Predicate push downs
#
# ![Catalyst](https://files.training.databricks.com/images/105/catalyst-diagram.png)

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) count()
#
# How many rows are in our dataset? Let's use the `count()` action to find out!
#
# Take a look at the [documentation
# ](https://spark.apache.org/docs/latest/api/python/pyspark.sql.html)to see how to use `count()`.

# %%
total = retailDF.count()

print("Record Count: {:,}".format( total ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Record Count: 40
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) select(..)
#
# In our case, the `img` column is of no value to us.
#
# We can disregard it by selecting only the 5 columns that we want:

# %%
minusOneDF = retailDF.select("product_id", "category", "brand", "model", "price")
  
minusOneDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- product_id: integer (nullable = true)
# -- category: string (nullable = true)
# -- brand: string (nullable = true)
# -- model: string (nullable = true)
# -- price: double (nullable = true)
#
# </div>

# %% [markdown]
# Again, notice how the call to `select(..)` does not trigger a job. That's because `select(..)` is a transformation.
#
# Let's go ahead and invoke the action `show(..)` and take a look at the result.

# %%
minusOneDF.show(5) #Since we did not specify an argument for Truncate, it defaults to True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+--------------------+-----------------+
# product_id|category|    brand|               model|            price|
# +----------+--------+---------+--------------------+-----------------+
#          1|Laptops |       HP|&quot;Spectre x360 2-i...|1499.989990234375|
#          2|Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;|1299.989990234375|
#          3|Laptops |Microsoft|Surface Book 2 - ...|1499.989990234375|
#          4|Laptops |     Dell|   XPS 2-in-1 13.3&quot;&quot;|1949.989990234375|
#          5|Laptops |   Lenovo|Yoga 920 2-in-1 1...|1799.989990234375|
# +----------+--------+---------+--------------------+-----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) drop(..)
#
# As a quick side note, you will quickly discover there are a lot of ways to accomplish the same task.
#
# Instead of selecting everything we wanted, `drop(..)` allows us to specify the columns we don't want.
#
# And we can see that we can produce the exact same result as the last exercise this way:

# %%
droppedDF = retailDF.drop("processor")

droppedDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- product_id: integer (nullable = true)
# -- category: string (nullable = true)
# -- brand: string (nullable = true)
# -- model: string (nullable = true)
# -- price: double (nullable = true)
# -- size: string (nullable = true)
# -- display: string (nullable = true)
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) withColumnRenamed(..)
#
# There are many ways to rename columns of a DataFrame in Spark.
#
# `withColumnRenamed(oldName, newName)` allows to rename columns one at a time.

# %%
droppedDF.withColumnRenamed("product_id", "prodID").printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- prodID: integer (nullable = true)
# -- category: string (nullable = true)
# -- brand: string (nullable = true)
# -- model: string (nullable = true)
# -- price: double (nullable = true)
# -- size: string (nullable = true)
# -- display: string (nullable = true)
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) withColumn(..)
#
# `withColumn` allows us to add new columns, or overwrite the values of existing columns.
#
# Let's make a new column which equals double the `price` field. There are a few ways we can do this.
#
# One is by importing the `col` (column) function and applying it to the `price` column (recommended).

# %%
from pyspark.sql.functions import col

doublePriceDF = droppedDF.withColumn("doublePrice", col("price") * 2)

doublePriceDF.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+--------------------+-----------------+----+-------+----------------+
# product_id|category|    brand|               model|            price|size|display|     doublePrice|
# +----------+--------+---------+--------------------+-----------------+----+-------+----------------+
#          1|Laptops |       HP|&quot;Spectre x360 2-i...|1499.989990234375|null|   null|2999.97998046875|
#          2|Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;|1299.989990234375|null|   null|2599.97998046875|
#          3|Laptops |Microsoft|Surface Book 2 - ...|1499.989990234375|null|   null|2999.97998046875|
# +----------+--------+---------+--------------------+-----------------+----+-------+----------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# Another way is to use Python Pandas syntax i.e. `droppedDF["price"]` as shown below.

# %%
droppedDF.withColumn("doublePrice", droppedDF["price"] * 2).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+---------+--------------------+-----------------+----+-------+----------------+
# product_id|category|    brand|               model|            price|size|display|     doublePrice|
# +----------+--------+---------+--------------------+-----------------+----+-------+----------------+
#          1|Laptops |       HP|&quot;Spectre x360 2-i...|1499.989990234375|null|   null|2999.97998046875|
#          2|Laptops |Microsoft|Surface Pro – 12.3&quot;&quot;|1299.989990234375|null|   null|2599.97998046875|
#          3|Laptops |Microsoft|Surface Book 2 - ...|1499.989990234375|null|   null|2999.97998046875|
# +----------+--------+---------+--------------------+-----------------+----+-------+----------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# Above, we used the `col("price")` or `droppedDF["price"] * 2` syntax.
#
# Using this syntax will not work:
# `droppedDF.withColumn("doublePrice", "price")`
#
# * The problem is that `.withColumn(..)` expects a column type, thus the notation
# `col("price") * 2` or `droppedDF["price"] * 2`
#
# Refer to:
# https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.withColumn

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) The Column Class
#
# The `Column` class is an object that encompasses more than just the name of the column, but also column-level-transformations, such as sorting in a descending order.
#
# The first question to ask is how do I create a `Column` object?
#
# In Python we have these options:

# %%
# Scala & Python both support accessing a column from a known DataFrame
columnA = retailDF["price"]
print(columnA)

columnB = retailDF.price
print(columnB)

# The $"column-name" version that works for Scala does not work in Python

# If we import ...sql.functions, we get a couple of more options:
from pyspark.sql.functions import *

# This uses the col(..) function
columnC = col("price")
print(columnC)

# This uses the expr(..) function which parses an SQL Expression
columnD = expr("a + 1")
print(columnD)

# This uses the lit(..) to create a literal (constant) value.
columnE = lit("abc")
print(columnE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Column&lt;b&apos;price&apos;&gt;
# Column&lt;b&apos;price&apos;&gt;
# Column&lt;b&apos;price&apos;&gt;
# Column&lt;b&apos;(a + 1)&apos;&gt;
# Column&lt;b&apos;abc&apos;&gt;
# </div>

# %% [markdown]
# In the case of Python, the cleanest version is the **col("column-name")** variant.
#
# ** *Note:* ** *We are introducing `...sql.functions` specifically for creating `Column` objects.*<br/>
# *We will be reviewing the multitude of other commands available from this part of the API in future notebooks.*

# %%
display(droppedDF.withColumn("doubleReq", col("price") * 2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>size</th><th>display</th><th>doubleReq</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>2999.97998046875</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.
</td><td>299.99</td><td>599.98</td></tr><tr><td>30</td><td>tablets</td><td>Samsung</td><td>299.99</td><td>599.98</td></tr><tr><td>31</td><td>tablets</td><td>Samsung</td><td>299.99</td><td>599.98</td></tr><tr><td>32</td><td>tablets</td><td>Fujitsu</td><td>299.99</td><td>599.98</td></tr><tr><td>33</td><td>tablets</td><td>Dell</td><td>299.99</td><td>599.98</td></tr><tr><td>34</td><td>tablets</td><td>Dell</td><td>299.99</td><td>599.98</td></tr><tr><td>35</td><td>tablets</td><td>ASUS</td><td>299.99</td><td>599.98</td></tr><tr><td>36</td><td>tablets</td><td>Lenovo&amp;reg;</td><td>299.99</td><td>599.98</td></tr><tr><td>37</td><td>tablets</td><td>Lenovo&amp;reg;</td><td>299.99</td><td>599.98</td></tr><tr><td>38</td><td>tablets</td><td>Cube&amp;reg;</td><td>299.99</td><td>599.98</td></tr><tr><td>39</td><td>tablets</td><td>Eve </td><td>299.99</td><td>599.98</td></tr><tr><td>40</td><td>tablets</td><td>Fujitsu</td><td>299.99</td><td>599.98</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) filter
#
# Let's filter out all of the records where the number of requests is less than 100.

# %%
display(retailDF.filter("price >= 300"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>category</th><th>brand</th><th>model</th><th>price</th><th>processor</th><th>size</th><th>display</th></tr></thead><tbody><tr><td>1</td><td>Laptops </td><td>HP</td><td>"Spectre x360 2-in-1 13.3"" 4K Ultra HD Touch-Screen Laptop"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3""</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Laptops </td><td>Microsoft</td><td>Surface Book 2 - 13.5""</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>4</td><td>Laptops </td><td>Dell</td><td>XPS 2-in-1 13.3""</td><td>1949.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Laptops </td><td>Lenovo</td><td>Yoga 920 2-in-1 13.9""</td><td>1799.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15"" Display"</td><td>2659.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 13"" Display"</td><td>1499.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Laptops </td><td>Apple </td><td>"MacBook Pro - 15.4"" Display"</td><td>1999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>9</td><td>Laptops </td><td>Apple </td><td>"MacBook Air - 13.3"" Display"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Laptops </td><td>HP</td><td>"Pavilion x360 2-in-1 14"" Touch-Screen Laptop"</td><td>999.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>11</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>12</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 Pro 13.3"" Touch-Screen Laptop"</td><td>1099.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>13</td><td>Laptops </td><td>Google</td><td>"Pixelbook 12.3"" Touchscreen Chromebook"</td><td>1699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>14</td><td>Laptops </td><td>Samsung</td><td>"Notebook 9 spin 13.3"" Touch-Screen Laptop"</td><td>1199.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>15</td><td>Laptops </td><td>Dell</td><td>"15.6"" Laptop"</td><td>2279.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Laptops </td><td>Dell</td><td>"2-in-1 17.3"" Touch-Screen Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>Laptops </td><td>Microsoft</td><td>"Surface Book 13.5"" Touch Screen with Performance Base"</td><td>2399.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>18</td><td>Laptops </td><td>Lenovo</td><td>"Star Wars Special Edition Galactic Empire - Yoga 910 2-in-1 13.9"" Laptop"</td><td>1299.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>19</td><td>Laptops </td><td>Microsoft</td><td>Surface Pro – 12.3”</td><td>2699.989990234375</td><td>null</td><td>null</td><td>null</td></tr><tr><td>20</td><td>Laptops </td><td>Lenovo</td><td>"15.6"" Laptop"</td><td>2499.989990234375</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) groupBy
#
# Let's group by the `project` field in our dataset.
#
# Look at the [docs](https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData) to see all of the different methods we can call on groupedData.

# %%
display(retailDF.groupBy("brand").count().filter("brand = 'Microsoft'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th><th>count</th></tr></thead><tbody><tr><td>Microsoft</td><td>5</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) take(n)
#
# Use `take` if you want to retrieve just a few records of your data.

# %%
retailDF.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
# [Row(product_id=1, category=&apos;Laptops &apos;, brand=&apos;HP&apos;, model=&apos;&quot;Spectre x360 2-in-1 13.3&quot;&quot; 4K Ultra HD Touch-Screen Laptop&quot;&apos;, price=1499.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=2, category=&apos;Laptops &apos;, brand=&apos;Microsoft&apos;, model=&apos;Surface Pro – 12.3&quot;&quot;&apos;, price=1299.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=3, category=&apos;Laptops &apos;, brand=&apos;Microsoft&apos;, model=&apos;Surface Book 2 - 13.5&quot;&quot;&apos;, price=1499.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=4, category=&apos;Laptops &apos;, brand=&apos;Dell&apos;, model=&apos;XPS 2-in-1 13.3&quot;&quot;&apos;, price=1949.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=5, category=&apos;Laptops &apos;, brand=&apos;Lenovo&apos;, model=&apos;Yoga 920 2-in-1 13.9&quot;&quot;&apos;, price=1799.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=6, category=&apos;Laptops &apos;, brand=&apos;Apple &apos;, model=&apos;&quot;MacBook Pro - 15&quot;&quot; Display&quot;&apos;, price=2659.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=7, category=&apos;Laptops &apos;, brand=&apos;Apple &apos;, model=&apos;&quot;MacBook Pro - 13&quot;&quot; Display&quot;&apos;, price=1499.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=8, category=&apos;Laptops &apos;, brand=&apos;Apple &apos;, model=&apos;&quot;MacBook Pro - 15.4&quot;&quot; Display&quot;&apos;, price=1999.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=9, category=&apos;Laptops &apos;, brand=&apos;Apple &apos;, model=&apos;&quot;MacBook Air - 13.3&quot;&quot; Display&quot;&apos;, price=999.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;),
#  Row(product_id=10, category=&apos;Laptops &apos;, brand=&apos;HP&apos;, model=&apos;&quot;Pavilion x360 2-in-1 14&quot;&quot; Touch-Screen Laptop&quot;&apos;, price=999.989990234375, processor=&apos;null&apos;, size=&apos;null&apos;, display=&apos;null&apos;)]
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) collect()
#
# Collect returns all of the data to the driver - calling collect on a large dataset is the easiest way to crash a Spark cluster. You want to be very careful when you use `collect`.

# %%
retailDF.groupBy("brand").count().limit(40).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>
# [Row(brand=&apos;Huawai&apos;, count=1),
#  Row(brand=&apos;Lenovo&amp;amp;reg;&apos;, count=2),
#  Row(brand=&apos;HP&amp;amp;reg;&apos;, count=4),
#  Row(brand=&apos;Fujitsu&apos;, count=2),
#  Row(brand=&apos;HP&apos;, count=2),
#  Row(brand=&apos;Dell&apos;, count=6),
#  Row(brand=&apos;Apple &apos;, count=4),
#  Row(brand=&apos;Acer&apos;, count=1),
#  Row(brand=&apos;Lenovo&apos;, count=3),
#  Row(brand=&apos;Samsung&apos;, count=4),
#  Row(brand=&apos;Eve &apos;, count=1),
#  Row(brand=&apos;Google&apos;, count=1),
#  Row(brand=&apos;Microsoft&apos;, count=5),
#  Row(brand=&apos;ASUS&apos;, count=1),
#  Row(brand=&apos;Chuwi&amp;amp;reg;&apos;, count=1),
#  Row(brand=&apos;Cube&amp;amp;reg;&apos;, count=1),
#  Row(brand=&apos;Porsche Design&apos;, count=1)]
# </div>

# %% [markdown]
# ## Next Step
#
# [Streaming]($../3-Streaming/3-01 Streaming)

# %% [markdown]
# -sandbox
# &copy; 2018 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
